# %% [markdown]
# # **Balanced: MLP**

# %% [markdown]
# # **Cybersecurity Network Traffic Dataset: Baseline**
#
# This dataset contains **network traffic records used for cybersecurity analysis**, specifically focused on detecting **Distributed Denial of Service (DDoS) and network flooding attacks**.
# Each CSV file represents traffic captured during a **specific attack type or normal network behavior**.
#
#
# The dataset is divided into multiple CSV files, each corresponding to a specific attack category or normal traffic type.
#
# | File | Description |
# |-----|-------------|
# | `DrDoS_DNS.csv` | DNS amplification Distributed Reflection Denial of Service attack traffic |
# | `DrDoS_LDAP.csv` | LDAP reflection DDoS attack traffic |
# | `DrDoS_MSSQL.csv` | MSSQL reflection DDoS attack traffic |
# | `DrDoS_NetBIOS.csv` | NetBIOS reflection DDoS attack traffic |
# | `DrDoS_NTP.csv` | NTP amplification attack traffic |
# | `DrDoS_SNMP.csv` | SNMP reflection DDoS attack traffic |
# | `DrDoS_SSDP.csv` | SSDP reflection DDoS attack traffic |
# | `DrDoS_UDP.csv` | UDP flood distributed denial of service traffic |
# | `Syn.csv` | SYN flood attack traffic |
#
# These attack types are examples of volumetric or reflection-based DDoS attacks, where attackers overwhelm a server or network by generating massive traffic.
#
# For training, we only consider the following CSV files due to limited computational resources. These CSV files were selected because these traffic types are commonly associated with reflection and amplification attacks. In these attacks, the attacker sends spoofed requests to legitimate servers (such as DNS, LDAP, or NTP services). The source IP address is forged to appear as the victim's address. As a result, the legitimate server sends the response to the victim instead of the attacker. Therefore, the analysis will focus on the following datasets:
#
# - **DNS.csv**
# - **LDAP.csv**
# - **NTP.csv**
# - **Syn.csv**

# %% [markdown]
# ### **00 Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)
import seaborn as sns
import time
import json
import os

# %%
def confusion_matrix_heatmap(
    y_true,
    y_pred,
    save_dir,
    model_name="Model",
    normalize=False,
    figsize=(7, 6),
    dpi=600
):
    """
    Generates and saves a publication-quality confusion matrix heatmap.

    Parameters:
    - y_true : array-like
        Ground truth labels.
    - y_pred : array-like
        Predicted labels.
    - model_name : str
        Name used for plot title and export filename.
    - normalize : bool
        If True, displays normalized percentages.
    - figsize : tuple
        Figure size.

    dpi : int
        Export image quality.
    """

    save_dir = os.path.join("results", "plots")
    os.makedirs(save_dir, exist_ok=True)

    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
        fmt = ".2f"
    else:
        fmt = "d"

    # Labels
    labels = ["No Attack", "Attack"]
    plt.style.use("seaborn-v0_8-white")
    fig, ax = plt.subplots(figsize=figsize, dpi=dpi)

    sns.heatmap(
        cm,
        annot=True,
        fmt=fmt,
        cmap="Blues",
        cbar=True,
        square=True,
        linewidths=1,
        linecolor="black",
        xticklabels=labels,
        yticklabels=labels,
        annot_kws={
            "size": 13,
            "weight": "bold"
        },
        ax=ax
    )

    # Titles and labels
    ax.set_title(
        f"{model_name} Confusion Matrix",
        fontsize=16,
        weight="bold",
        pad=15
    )

    ax.set_xlabel(
        "Predicted Label",
        fontsize=13,
        weight="bold"
    )

    ax.set_ylabel(
        "True Label",
        fontsize=13,
        weight="bold"
    )

    # Tick formatting
    ax.tick_params(axis='both', labelsize=11)

    plt.xticks(rotation=0)
    plt.yticks(rotation=0)

    # Improve spacing
    plt.tight_layout()

    # Export paths
    png_path = os.path.join(
        save_dir,
        f"{model_name.lower().replace(' ', '_')}_confusion_matrix.png"
    )

    pdf_path = os.path.join(
        save_dir,
        f"{model_name.lower().replace(' ', '_')}_confusion_matrix.pdf"
    )

    # Save figures
    plt.savefig(png_path, dpi=dpi, bbox_inches="tight")    
    plt.savefig(pdf_path, bbox_inches="tight")
        
    print(f"Confusion matrix saved to:")
    print(f" - {png_path}")
    print(f" - {pdf_path}")

    plt.show()

# %% [markdown]
# ### **01 Load Dataset**

# %% [markdown]
# The preprocessed dataset generated in the `02_Preprocessed.ipynb` notebook was loaded for the training phase.
#
# After loading the dataset:
#
# 1. The target variable (`Label`) was separated from the feature set.
# 2. The label column was removed from the input features to avoid data leakage during training.
# 3. Feature scaling was applied using `StandardScaler`.
#
# Standardization was performed to normalize the feature distributions and improve neural network convergence during training.
#
# This preprocessing step ensures that all numerical features contribute proportionally during optimization and model training.

# %%
path = r"C:\\Users\\Ale\\Documents\\NN-Labs\\Midterm\\Optuna-MLP-DDoS-detection\\Data_Preprocessing\\preprocessed_data"
train_path = f"{path}/train.csv"
val_path = f"{path}/val.csv"
test_path = f"{path}/test.csv"

# %%
train = pd.read_csv(train_path)
val = pd.read_csv(val_path)
test = pd.read_csv(test_path)

# %%
# Train
X_train = train.drop(["Label"], axis=1)
y_train = train["Label"]

# Validation
X_val = val.drop(["Label"], axis=1)
y_val = val["Label"]

# Test
X_test = test.drop(["Label"], axis=1)
y_test = test["Label"]

# %%
X_train = X_train.astype('float32')
X_val   = X_val.astype('float32')
X_test  = X_test.astype('float32')

# %%
print(X_train.shape)
print(X_train.dtypes)
print(X_train.info())
# Out:
# (25059, 63)
# Unnamed: 0          float32
# Source Port         float32
# Destination Port    float32
# Protocol            float32
# Flow Duration       float32
#                      ...
# Idle Mean           float32
# Idle Std            float32
# Idle Max            float32
# Idle Min            float32
# Inbound             float32
# Length: 63, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25059 entries, 0 to 25058
# Data columns (total 63 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   25059 non-null  float32
#  1   Source Port                  25059 non-null  float32
#  2   Destination Port             25059 non-null  float32
#  3   Protocol                     25059 non-null  float32
#  4   Flow Duration                25059 non-null  float32
#  5   Total Fwd Packets            25059 non-null  float32
#  6   Total Backward Packets       25059 non-null  float32
#  7   Total Length of Fwd Packets  25059 non-null  float32
#  8   Total Length of Bwd Packets  25059 non-null  float32
#  9   Fwd Packet Length Max        25059 non-null  float32
#  10  Fwd Packet Length Min        25059 non-null  float32
#  11  Fwd Packet Length Mean       25059 non-null  float32
#  12  Fwd Packet Length Std        25059 non-null  float32
#  13  Bwd Packet Length Max        25059 non-null  float32
#  14  Bwd Packet Length Min        25059 non-null  float32
#  15  Bwd Packet Length Mean       25059 non-null  float32
#  16  Bwd Packet Length Std        25059 non-null  float32
#  17  Flow Bytes/s                 25059 non-null  float32
#  18  Flow Packets/s               25059 non-null  float32
#  19  Flow IAT Mean                25059 non-null  float32
#  20  Flow IAT Std                 25059 non-null  float32
#  21  Flow IAT Max                 25059 non-null  float32
#  22  Flow IAT Min                 25059 non-null  float32
#  23  Fwd IAT Total                25059 non-null  float32
#  24  Fwd IAT Mean                 25059 non-null  float32
#  25  Fwd IAT Std                  25059 non-null  float32
#  26  Fwd IAT Max                  25059 non-null  float32
#  27  Fwd IAT Min                  25059 non-null  float32
#  28  Bwd IAT Total                25059 non-null  float32
#  29  Bwd IAT Mean                 25059 non-null  float32
#  30  Bwd IAT Std                  25059 non-null  float32
#  31  Bwd IAT Max                  25059 non-null  float32
#  32  Bwd IAT Min                  25059 non-null  float32
#  33  Fwd PSH Flags                25059 non-null  float32
#  34  Fwd Header Length            25059 non-null  float32
#  35  Bwd Header Length            25059 non-null  float32
#  36  Fwd Packets/s                25059 non-null  float32
#  37  Bwd Packets/s                25059 non-null  float32
#  38  Min Packet Length            25059 non-null  float32
#  39  Max Packet Length            25059 non-null  float32
#  40  Packet Length Mean           25059 non-null  float32
#  41  Packet Length Std            25059 non-null  float32
#  42  Packet Length Variance       25059 non-null  float32
#  43  SYN Flag Count               25059 non-null  float32
#  44  ACK Flag Count               25059 non-null  float32
#  45  URG Flag Count               25059 non-null  float32
#  46  CWE Flag Count               25059 non-null  float32
#  47  Down/Up Ratio                25059 non-null  float32
#  48  Average Packet Size          25059 non-null  float32
#  49  Avg Bwd Segment Size         25059 non-null  float32
#  50  Init_Win_bytes_forward       25059 non-null  float32
#  51  Init_Win_bytes_backward      25059 non-null  float32
#  52  act_data_pkt_fwd             25059 non-null  float32
#  53  min_seg_size_forward         25059 non-null  float32
#  54  Active Mean                  25059 non-null  float32
#  55  Active Std                   25059 non-null  float32
#  56  Active Max                   25059 non-null  float32
#  57  Active Min                   25059 non-null  float32
#  58  Idle Mean                    25059 non-null  float32
#  59  Idle Std                     25059 non-null  float32
#  60  Idle Max                     25059 non-null  float32
#  61  Idle Min                     25059 non-null  float32
#  62  Inbound                      25059 non-null  float32
# dtypes: float32(63)
# memory usage: 6.0 MB
# None

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **1. Baseline Model**
#
# A baseline neural network model was defined in order to establish a reference point for comparison with the Optuna multi-objective optimization process.
#
# This baseline architecture was intentionally designed as a simple feedforward neural network with a fixed structure. The objective is to evaluate how much performance improvement can be achieved after hyperparameter optimization.
#
# The model consists of:
#
# - An input layer connected to:
#   - A hidden layer with 32 neurons
#   - A second hidden layer with 16 neurons
# - A final output layer using a sigmoid activation function for binary classification
#
# The sigmoid activation function was selected because the problem is formulated as a binary classification task, where the model predicts whether the network traffic corresponds to normal behavior or an attack.
#
# The baseline architecture serves as the reference model against which the optimized Optuna-generated architectures are compared in terms of:
#
# - F1-score
# - Prediction time
# - Overall classification performance

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def create_baseline_model(input_dim):

    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(32, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            keras.metrics.AUC(name="auc")
        ]
    )

    return model

# %% [markdown]
# ## **Baseline Architecture**
#
# | **Layer** | **Configuration** |
# |---|---|
# | Hidden Layer 1 | 32 neurons |
# | Hidden Layer 2 | 16 neurons |
# | Output Layer | 1 neuron + Sigmoid |

# %%
model = create_baseline_model(X_train.shape[1])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                2048
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 2593 (10.13 KB)
# Trainable params: 2593 (10.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=256,
    verbose=1
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 98/98 [==============================] - 1s 4ms/step - loss: 0.3319 - accuracy: 0.8919 - auc: 0.9654 - val_loss: 0.0971 - val_accuracy: 0.9872 - val_auc: 0.9987
# Epoch 2/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 0.9958 - auc: 0.9995 - val_loss: 0.0307 - val_accuracy: 0.9976 - val_auc: 0.9991
# Epoch 3/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.9977 - auc: 0.9996 - val_loss: 0.0189 - val_accuracy: 0.9976 - val_auc: 0.9993
# Epoch 4/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9979 - auc: 0.9996 - val_loss: 0.0136 - val_accuracy: 0.9976 - val_auc: 0.9993
# Epoch 5/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9980 - auc: 0.9996 - val_loss: 0.0113 - val_accuracy: 0.9978 - val_auc: 0.9996
# Epoch 6/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9981 - auc: 0.9997 - val_loss: 0.0106 - val_accuracy: 0.9979 - val_auc: 0.9996
# Epoch 7/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9981 - auc: 0.9998 - val_loss: 0.0101 - val_accuracy: 0.9979 - val_auc: 0.9996
# Epoch 8/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9982 - auc: 0.9997 - val_loss: 0.0096 - val_accuracy: 0.9979 - val_auc: 0.9995
# Epoch 9/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.9983 - auc: 0.9997 - val_loss: 0.0092 - val_accuracy: 0.9979 - val_auc: 0.9995
# Epoch 10/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9982 - auc: 0.9997 - val_loss: 0.0088 - val_accuracy: 0.9979 - val_auc: 0.9995
# Epoch 11/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 0.9985 - auc: 0.9998 - val_loss: 0.0084 - val_accuracy: 0.9979 - val_auc: 0.9996
# Epoch 12/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 0.9986 - auc: 0.9998 - val_loss: 0.0083 - val_accuracy: 0.9982 - val_auc: 0.9996
# Epoch 13/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9988 - auc: 0.9999 - val_loss: 0.0077 - val_accuracy: 0.9981 - val_auc: 0.9996
# Epoch 14/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9984 - auc: 0.9999 - val_loss: 0.0076 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 15/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 0.9988 - auc: 0.9999 - val_loss: 0.0073 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 16/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 0.9988 - auc: 0.9999 - val_loss: 0.0073 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 17/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 0.9991 - auc: 0.9999 - val_loss: 0.0071 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 18/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 0.9992 - auc: 0.9999 - val_loss: 0.0071 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 19/20
# 98/98 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 0.9992 - auc: 0.9999 - val_loss: 0.0069 - val_accuracy: 0.9984 - val_auc: 0.9998
# Epoch 20/20
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9984 - val_auc: 0.9998

# %% [markdown]
# Proving with testing and time measurement

# %%
times = []
# Warmup
model.predict(
    X_test[:1],
    verbose=0
)

for _ in range(100):
    start = time.perf_counter()
    model.predict(
        X_test[:1],
        verbose=0
    )

    end = time.perf_counter()
    times.append(end - start)

# Average latency in milliseconds
baseline_inference_time_ms = float(
    np.mean(times) * 1000
)

# %%
y_pred_probs = model.predict(
    X_test,
    batch_size=4096,
    verbose=1
)

y_pred = (y_pred_probs > 0.5).astype(int).flatten()

print(
    f"Baseline Inference Time: "
    f"{baseline_inference_time_ms:.4f} ms/sample"
)
# Out:
# 471/471 [==============================] - 1s 1ms/step
# Baseline Inference Time: 52.1893 ms/sample

# %% [markdown]
# ### **Metrics**

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("AUC:", tf.keras.metrics.AUC()(y_test, y_pred_probs).numpy() )

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9993286318554075
# Precision: 0.9999968810089312
# Recall: 0.9993303833490391
# F1 Score: 0.9996635210868346
# AUC: 0.99972534
#
# Confusion Matrix:
# [[   3909       6]
#  [   1289 1923693]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86      3915
#            1       1.00      1.00      1.00   1924982
#
#     accuracy                           1.00   1928897
#    macro avg       0.88      1.00      0.93   1928897
# weighted avg       1.00      1.00      1.00   1928897

# %% [markdown]
# ### **Export Results in json format**

# %%
results = {

    "accuracy": float(
        accuracy_score(y_test, y_pred)
    ),

    "precision": float(
        precision_score(y_test, y_pred)
    ),

    "recall": float(
        recall_score(y_test, y_pred)
    ),

    "f1_score": float(
        f1_score(y_test, y_pred)
    ),

    "auc": float(
        tf.keras.metrics.AUC()(
            y_test,
            y_pred_probs
        ).numpy()
    ),

    "inference_time_ms": baseline_inference_time_ms,

    "confusion_matrix": confusion_matrix(
        y_test,
        y_pred
    ).tolist(),

    "classification_report": classification_report(
        y_test,
        y_pred,
        output_dict=True
    )
}

# %%
os.makedirs("results/balanced", exist_ok=True)

with open("results/balanced/evaluation_results_balanced_baseline.json", "w") as f:

    json.dump(
        results,
        f,
        indent=4
    )

print("Results exported to results/balanced/evaluation_results_balanced_baseline.json")
# Out:
# Results exported to results/balanced/evaluation_results_balanced_baseline.json

# %% [markdown]
# ### **Confusion Matrix**

# %%
confusion_matrix_heatmap(y_test, y_pred, save_dir="results/balanced", model_name="Balanced Baseline MLP",)
# Out:
# Confusion matrix saved to:
#  - results\plots\balanced_baseline_mlp_confusion_matrix.png
#  - results\plots\balanced_baseline_mlp_confusion_matrix.pdf

# %% [markdown]
# # **2. Optuna Optimization**
#
# To improve the performance of the baseline neural network, a multi-objective hyperparameter optimization process was implemented using **Optuna**. Optuna is an automatic hyperparameter optimization framework designed to efficiently explore large search spaces and identify optimal model configurations.
#
# In this project, Optuna was used to optimize the neural network architecture and training parameters while simultaneously considering two objectives:
#
# - Maximize the F1-score
# - Minimize prediction time
#
# This approach allows the identification of models that not only achieve high classification performance but also maintain low inference latency for real-time cybersecurity applications.

# %%
#import sys
#!{sys.executable} -m pip install plotly

# %%
#import sys
#!{sys.executable} -m pip install optuna

# %%
import time
import numpy as np
import optuna
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### **Optimization Strategy**
#
# The study was configured as a **multi-objective optimization problem**, where each trial generates a different neural network configuration.
#
# For every trial, Optuna evaluates:
#
# 1. Neural network architecture
# 2. Learning rate
# 3. Batch size
# 4. Number of hidden layers
# 5. Hidden layer dimensions
#
# The resulting model is then trained and evaluated using the validation dataset.
#
# The following hyperparameters were explored during optimization:
#
# | Hyperparameter | Search Range |
# |---|---|
# | Hidden layer size | 32 → 256 |
# | Number of hidden layers | 1 → 5 |
# | Learning rate | 1e-5 → 1e-2 |
# | Batch size | 32, 64, 128 |

# %%
RANDOM_STATE = 42
N_TRIALS = 100
N_RUNS_TIMING = 10

# Hidden layer size range
HIDDEN_SIZE_MIN = 32
HIDDEN_SIZE_MAX = 256

# Number of hidden layers
NUM_LAYERS_MIN = 1
NUM_LAYERS_MAX = 5

# Learning rate range
LR_MIN = 1e-5
LR_MAX = 1e-2

# Batch size options
BATCH_SIZES = [32, 64, 128]

# Optimization directions
DIRECTIONS = ["maximize", "minimize"]

# %% [markdown]
# ### **Multi-Objective Optimization**
#
# The optimization process simultaneously evaluates:
#
# | Objective | Goal |
# |---|---|
# | F1-score | Maximize |
# | Prediction time | Minimize |
#
# Because these objectives are conflicting, Optuna generates a **Pareto Front**, which contains the set of optimal trade-off solutions.
#
# Some models may achieve:
#
# - Higher classification accuracy with slower inference
# - Faster prediction speed with slightly lower performance
#
# This methodology allows selecting models according to system requirements and computational constraints.

# %%
def build_model(hidden_size, lr, num_layers):

    model = keras.Sequential()

    # Input layer + first hidden layer
    model.add(
        layers.Dense(
            hidden_size,
            activation="relu",
            input_shape=(X_train.shape[1],)
        )
    )

    # Additional hidden layers
    current_size = hidden_size

    for _ in range(num_layers - 1):

        # Optional progressive reduction
        current_size = max(current_size // 2, 16)

        model.add(
            layers.Dense(
                current_size,
                activation="relu"
            )
        )

    # Output layer
    model.add(
        layers.Dense(1, activation="sigmoid")
    )

    # Optimizer
    optimizer = keras.optimizers.Adam(
        learning_rate=lr
    )

    # Compile model
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
def train_and_evaluate(model, batch_size):

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=10,
        batch_size=batch_size,
        verbose=0
    )

    # Predictions
    y_pred = model.predict(X_val, verbose=0)

    # Convert probabilities to binary labels
    y_pred = (y_pred > 0.5).astype(int).flatten()

    # F1-score
    f1 = f1_score(y_val, y_pred)

    # Validation loss
    val_loss = history.history["val_loss"][-1]

    return val_loss, f1

# %% [markdown]
# ### **Prediction Time Evaluation**
#
# Inference latency was incorporated as a second optimization objective in order to evaluate real-time applicability.
#
# Prediction time was measured multiple times to reduce noise and variability:
# The average prediction time across all runs was used during optimization.

# %%
import time
import numpy as np

def measure_inference_time(model, X_val, n_runs=N_RUNS_TIMING):
    # Single sample
    sample = X_val[:1]
    times = []

    # Warmup
    model.predict(sample, verbose=0)

    for _ in range(n_runs):
        start = time.perf_counter()
        model.predict(sample, verbose=0)
        end = time.perf_counter()
        times.append(end - start)

    return float(np.mean(times))

# %%
def objective(trial):

    # Hyperparameters
    hidden_size = trial.suggest_int(
        "hidden_size",
        HIDDEN_SIZE_MIN,
        HIDDEN_SIZE_MAX
    )

    num_layers = trial.suggest_int(
        "num_layers",
        NUM_LAYERS_MIN,
        NUM_LAYERS_MAX
    )

    lr = trial.suggest_float(
        "lr",
        LR_MIN,
        LR_MAX,
        log=True
    )

    batch_size = trial.suggest_categorical(
        "batch_size",
        BATCH_SIZES
    )

    # Build model
    model = build_model(
        hidden_size=hidden_size,
        lr=lr,
        num_layers=num_layers
    )

    # Train and evaluate
    val_loss, f1 = train_and_evaluate(
        model,
        batch_size
    )

    # Measure inference speed
    inference_time = measure_inference_time(
        model,
        X_val
    )

    # Multi-objective optimization
    return f1, inference_time

# %%
def create_study():

    study = optuna.create_study(
        directions=DIRECTIONS,
        sampler=optuna.samplers.NSGAIISampler(seed=RANDOM_STATE)
    )

    return study

# %% [markdown]
# ### **Pareto Front Analysis**
# In this project, the optimization process simultaneously attempts to:
#
# - Maximize the F1-score
# - Minimize prediction time
#
# These objectives are inherently conflicting because more complex neural network architectures may achieve higher classification performance while also increasing computational cost and inference latency.
# To analyze this trade-off, Optuna generates a **Pareto Front**.
#
# A Pareto Front is the set of optimal solutions in a multi-objective optimization problem.
# A solution belongs to the Pareto Front if:
#
# - No other solution improves one objective without worsening the other.
# - Its F1-score cannot be improved without increasing prediction time.
# - Its prediction time cannot be reduced without decreasing F1-score.
#
# These solutions represent the best trade-offs discovered during optimization.
#
# ###  **Pareto Dominance**
#
# A model is said to dominate another model if:
#
# - It achieves equal or better performance in all objectives
# - And strictly better performance in at least one objective
#
# The Pareto Front provides multiple optimal candidate models rather than a single “best” solution.
#
# This allows selecting models depending on system requirements.
# During Optuna optimization:
#
# - Each trial generates a different neural network architecture.
# - Each model is evaluated using:
#   - F1-score
#   - Prediction time
#
# After all trials are completed, Optuna identifies the subset of non-dominated solutions.
#
# These solutions form the Pareto Front.
#
# The Pareto-optimal models represent the best balance between:
#
# - Detection capability
# - Computational efficiency

# %%
def print_pareto_front(study):

    pareto_trials = study.best_trials
    print(f"\nPareto-front trials: {len(pareto_trials)}")
    print("=" * 60)
    for t in pareto_trials:

        f1_score_val = t.values[0]
        inf_time_ms = t.values[1] * 1000
        print(
            f"Trial #{t.number:<3} | "
            f"F1-score: {f1_score_val:.4f} | "
            f"Inference Time: {inf_time_ms:.3f} ms"
        )
        print(f"Parameters: {t.params}")
        print("-" * 60)

# %%
def plot_pareto_front(study, save_path="pareto_balance"):
    if save_path not in os.listdir("results/balanced"):
        os.makedirs(save_path, exist_ok=True)
    pareto_trials = study.best_trials

    f1_scores = [t.values[0] for t in pareto_trials]

    inference_times = [
        t.values[1] * 1000
        for t in pareto_trials
    ]

    plt.figure(figsize=(7, 5), dpi=300)

    plt.scatter(
        inference_times,
        f1_scores,
        s=80,
        alpha=0.8
    )

    # Annotate each point with trial number
    for i, t in enumerate(pareto_trials):

        plt.annotate(
            f"T{t.number}",
            (inference_times[i], f1_scores[i]),
            textcoords="offset points",
            xytext=(5, 5),
            fontsize=9
        )

    plt.xlabel("Inference Time (ms)", fontsize=12)
    plt.ylabel("F1-score", fontsize=12)

    plt.title(
        "Pareto Front for Multi-Objective Optimization",
        fontsize=14,
        weight='bold'
    )

    plt.grid(True)

    plt.tight_layout()

    # Save publication-quality figure
    if save_path:
        plt.savefig(
            save_path,
            dpi=300,
            bbox_inches='tight'
        )

    plt.show()

# %% [markdown]
# ### **Training Workflow**
# Unlike the baseline model, the Optuna architecture is not fixed.
# The number of layers and neurons is dynamically generated according to the sampled hyperparameters.
# This allows the optimizer to explore multiple architectural combinations and identify efficient configurations.
#
# For each Optuna trial:
#
# 1. A neural network architecture is generated dynamically.
# 2. Hyperparameters are sampled from the search space.
# 3. The model is trained using the balanced training dataset.
# 4. Validation metrics are computed.
# 5. Prediction time is measured multiple times.
# 6. Both objectives are returned to the optimizer.
#
# The optimization process continues for a total of 100 trials.

# %%
study = create_study()
# Out:
# [I 2026-05-31 01:30:59,173] A new study created in memory with name: no-name-8e6c86c5-e7be-4d22-aab3-a1e8b3b4b158

# %%
study.optimize(objective, n_trials=50)
# Out:
# [I 2026-05-31 01:31:12,905] Trial 0 finished with values: [0.9987220447284345, 0.06647003999999583] and parameters: {'hidden_size': 116, 'num_layers': 5, 'lr': 0.001570297088405539, 'batch_size': 32}.
# [I 2026-05-31 01:31:18,198] Trial 1 finished with values: [0.9976042165788213, 0.06289221000000111] and parameters: {'hidden_size': 45, 'num_layers': 5, 'lr': 0.0006358358856676254, 'batch_size': 128}.
# [I 2026-05-31 01:31:24,072] Trial 2 finished with values: [0.9972891085951204, 0.06393170000000055] and parameters: {'hidden_size': 219, 'num_layers': 2, 'lr': 3.511356313970405e-05, 'batch_size': 128}.
# [I 2026-05-31 01:31:30,060] Trial 3 finished with values: [0.9985625299472928, 0.047724840000012134] and parameters: {'hidden_size': 129, 'num_layers': 2, 'lr': 0.000684792009557478, 'batch_size': 128}.
# [I 2026-05-31 01:31:36,616] Trial 4 finished with values: [0.9977664326738992, 0.04777647999999886] and parameters: {'hidden_size': 134, 'num_layers': 4, 'lr': 3.972110727381908e-05, 'batch_size': 64}.
# [I 2026-05-31 01:31:43,131] Trial 5 finished with values: [0.9944098386839163, 0.05639454000001933] and parameters: {'hidden_size': 168, 'num_layers': 1, 'lr': 1.5673095467235405e-05, 'batch_size': 64}.
# [I 2026-05-31 01:31:47,959] Trial 6 finished with values: [0.9977664326738992, 0.06782916000001364] and parameters: {'hidden_size': 100, 'num_layers': 1, 'lr': 0.0011290133559092666, 'batch_size': 128}.
# [I 2026-05-31 01:32:00,498] Trial 7 finished with values: [0.9980842911877394, 0.05570214999999053] and parameters: {'hidden_size': 39, 'num_layers': 5, 'lr': 5.9750279999602906e-05, 'batch_size': 32}.
# [I 2026-05-31 01:32:06,251] Trial 8 finished with values: [0.9984035759897829, 0.05072674999998981] and parameters: {'hidden_size': 155, 'num_layers': 1, 'lr': 0.008105016126411584, 'batch_size': 64}.
# [I 2026-05-31 01:32:11,147] Trial 9 finished with values: [0.9974473516273133, 0.0516462200000035] and parameters: {'hidden_size': 166, 'num_layers': 5, 'lr': 1.8427970406864546e-05, 'batch_size': 128}.
# [I 2026-05-31 01:32:15,587] Trial 10 finished with values: [0.9988830381362693, 0.060046119999992695] and parameters: {'hidden_size': 119, 'num_layers': 2, 'lr': 0.003063462210622081, 'batch_size': 128}.
# [I 2026-05-31 01:32:28,706] Trial 11 finished with values: [0.9976072738873824, 0.05842417000001206] and parameters: {'hidden_size': 63, 'num_layers': 5, 'lr': 1.6736010167825783e-05, 'batch_size': 32}.
# [I 2026-05-31 01:32:36,241] Trial 12 finished with values: [0.9985648221974167, 0.04716938000000255] and parameters: {'hidden_size': 33, 'num_layers': 5, 'lr': 0.001319994226153501, 'batch_size': 64}.
# [I 2026-05-31 01:32:45,823] Trial 13 finished with values: [0.9988830381362693, 0.05979193999999666] and parameters: {'hidden_size': 112, 'num_layers': 1, 'lr': 0.0038842777547031426, 'batch_size': 32}.
# [I 2026-05-31 01:32:53,185] Trial 14 finished with values: [0.9974432726110578, 0.06200517999999988] and parameters: {'hidden_size': 101, 'num_layers': 2, 'lr': 0.0015446089075047066, 'batch_size': 64}.
# [I 2026-05-31 01:32:59,924] Trial 15 finished with values: [0.9988830381362693, 0.052697039999998196] and parameters: {'hidden_size': 58, 'num_layers': 4, 'lr': 0.0019158219548093154, 'batch_size': 64}.
# [I 2026-05-31 01:33:04,266] Trial 16 finished with values: [0.9945617402431222, 0.045436779999999996] and parameters: {'hidden_size': 149, 'num_layers': 3, 'lr': 1.1919481947918725e-05, 'batch_size': 128}.
# [I 2026-05-31 01:33:08,411] Trial 17 finished with values: [0.9988830381362693, 0.048737409999989725] and parameters: {'hidden_size': 102, 'num_layers': 3, 'lr': 0.005280796376895365, 'batch_size': 128}.
# [I 2026-05-31 01:33:13,984] Trial 18 finished with values: [0.9976072738873824, 0.05498497000000953] and parameters: {'hidden_size': 83, 'num_layers': 1, 'lr': 7.40038575908737e-05, 'batch_size': 64}.
# [I 2026-05-31 01:33:22,148] Trial 19 finished with values: [0.9990418396678378, 0.05740833000000976] and parameters: {'hidden_size': 174, 'num_layers': 5, 'lr': 0.0025764174425233167, 'batch_size': 64}.
# [I 2026-05-31 01:33:28,039] Trial 20 finished with values: [0.998084902649218, 0.059654470000009494] and parameters: {'hidden_size': 213, 'num_layers': 5, 'lr': 8.995191735587162e-05, 'batch_size': 128}.
# [I 2026-05-31 01:33:41,955] Trial 21 finished with values: [0.9974481658692185, 0.05597717000000557] and parameters: {'hidden_size': 216, 'num_layers': 5, 'lr': 1.0491954332267901e-05, 'batch_size': 32}.
# [I 2026-05-31 01:33:46,364] Trial 22 finished with values: [0.9990418396678378, 0.05377054000000499] and parameters: {'hidden_size': 58, 'num_layers': 2, 'lr': 0.0067410742656406975, 'batch_size': 128}.
# [I 2026-05-31 01:33:54,554] Trial 23 finished with values: [0.9992016605460642, 0.05843816999999944] and parameters: {'hidden_size': 113, 'num_layers': 5, 'lr': 0.007715105777813051, 'batch_size': 64}.
# [I 2026-05-31 01:34:05,393] Trial 24 finished with values: [0.998404085541015, 0.04676336999999649] and parameters: {'hidden_size': 96, 'num_layers': 1, 'lr': 0.0006740513796374046, 'batch_size': 32}.
# [I 2026-05-31 01:34:22,555] Trial 25 finished with values: [0.9974481658692185, 0.1291200200000162] and parameters: {'hidden_size': 236, 'num_layers': 2, 'lr': 2.7207248059486674e-05, 'batch_size': 64}.
# [I 2026-05-31 01:34:53,572] Trial 26 finished with values: [0.998244213886672, 0.12841422999998714] and parameters: {'hidden_size': 183, 'num_layers': 4, 'lr': 5.163124910488014e-05, 'batch_size': 32}.
# [I 2026-05-31 01:35:20,030] Trial 27 finished with values: [0.9976072738873824, 0.04673218999998881] and parameters: {'hidden_size': 174, 'num_layers': 3, 'lr': 1.865818136012483e-05, 'batch_size': 32}.
# [I 2026-05-31 01:35:26,481] Trial 28 finished with values: [0.9984035759897829, 0.059944979999988844] and parameters: {'hidden_size': 41, 'num_layers': 3, 'lr': 0.001078184503512226, 'batch_size': 64}.
# [I 2026-05-31 01:35:33,164] Trial 29 finished with values: [0.9984035759897829, 0.06346268000002056] and parameters: {'hidden_size': 177, 'num_layers': 1, 'lr': 0.0011825328508422654, 'batch_size': 64}.
# [I 2026-05-31 01:35:44,640] Trial 30 finished with values: [0.9988823247644899, 0.06323371000001998] and parameters: {'hidden_size': 108, 'num_layers': 1, 'lr': 0.0059440281134109305, 'batch_size': 32}.
# [I 2026-05-31 01:35:52,692] Trial 31 finished with values: [0.9988819677367833, 0.12496917999998232] and parameters: {'hidden_size': 215, 'num_layers': 3, 'lr': 0.00038810723164094845, 'batch_size': 128}.
# [I 2026-05-31 01:36:05,615] Trial 32 finished with values: [0.9980842911877394, 0.1300518000000011] and parameters: {'hidden_size': 234, 'num_layers': 4, 'lr': 0.00010401341922663452, 'batch_size': 128}.
# [I 2026-05-31 01:36:18,980] Trial 33 finished with values: [0.9993614303959132, 0.12539778999998816] and parameters: {'hidden_size': 231, 'num_layers': 4, 'lr': 0.0008435191341743053, 'batch_size': 128}.
# [I 2026-05-31 01:36:33,608] Trial 34 finished with values: [0.9976072738873824, 0.04925157999999783] and parameters: {'hidden_size': 168, 'num_layers': 1, 'lr': 2.015647705936502e-05, 'batch_size': 32}.
# [I 2026-05-31 01:36:41,431] Trial 35 finished with values: [0.9988830381362693, 0.05595131999999694] and parameters: {'hidden_size': 155, 'num_layers': 4, 'lr': 0.0009034076805537766, 'batch_size': 64}.
# [I 2026-05-31 01:37:00,651] Trial 36 finished with values: [0.9987236758136566, 0.13049659999999222] and parameters: {'hidden_size': 105, 'num_layers': 4, 'lr': 0.0008889937283707153, 'batch_size': 32}.
# [I 2026-05-31 01:37:15,382] Trial 37 finished with values: [0.9974481658692185, 0.12718927000000804] and parameters: {'hidden_size': 53, 'num_layers': 2, 'lr': 6.246073681318086e-05, 'batch_size': 64}.
# [I 2026-05-31 01:37:33,860] Trial 38 finished with values: [0.9988830381362693, 0.13016180999999277] and parameters: {'hidden_size': 232, 'num_layers': 4, 'lr': 0.0024234491447023164, 'batch_size': 64}.
# [I 2026-05-31 01:37:49,478] Trial 39 finished with values: [0.9977664326738992, 0.05103370999999015] and parameters: {'hidden_size': 75, 'num_layers': 4, 'lr': 6.955319544158292e-05, 'batch_size': 64}.
# [I 2026-05-31 01:37:55,458] Trial 40 finished with values: [0.9987220447284345, 0.0629922400000055] and parameters: {'hidden_size': 243, 'num_layers': 5, 'lr': 0.005553837526912238, 'batch_size': 128}.
# [I 2026-05-31 01:38:09,211] Trial 41 finished with values: [0.9992016605460642, 0.056744129999981394] and parameters: {'hidden_size': 128, 'num_layers': 5, 'lr': 0.007777856590163646, 'batch_size': 32}.
# [I 2026-05-31 01:38:16,621] Trial 42 finished with values: [0.9976072738873824, 0.05145473000000038] and parameters: {'hidden_size': 223, 'num_layers': 2, 'lr': 3.22461774864237e-05, 'batch_size': 64}.
# [I 2026-05-31 01:38:26,367] Trial 43 finished with values: [0.9980861244019139, 0.055947930000013454] and parameters: {'hidden_size': 160, 'num_layers': 1, 'lr': 0.0006998769331752384, 'batch_size': 32}.
# [I 2026-05-31 01:38:40,187] Trial 44 finished with values: [0.9988830381362693, 0.054509320000033765] and parameters: {'hidden_size': 229, 'num_layers': 4, 'lr': 0.0012332389221028, 'batch_size': 32}.
# [I 2026-05-31 01:38:54,094] Trial 45 finished with values: [0.9984051036682615, 0.054902020000008635] and parameters: {'hidden_size': 214, 'num_layers': 5, 'lr': 0.003992242886631504, 'batch_size': 32}.
# [I 2026-05-31 01:39:02,479] Trial 46 finished with values: [0.998723268432812, 0.06144150999997464] and parameters: {'hidden_size': 211, 'num_layers': 4, 'lr': 0.0012761467881730222, 'batch_size': 64}.
# [I 2026-05-31 01:39:06,909] Trial 47 finished with values: [0.998404085541015, 0.055487800000003064] and parameters: {'hidden_size': 116, 'num_layers': 1, 'lr': 0.0005430507564500919, 'batch_size': 128}.
# [I 2026-05-31 01:39:14,276] Trial 48 finished with values: [0.9958492975734355, 0.0551556299999902] and parameters: {'hidden_size': 96, 'num_layers': 3, 'lr': 1.2345274466024455e-05, 'batch_size': 64}.
# [I 2026-05-31 01:39:21,437] Trial 49 finished with values: [0.9988830381362693, 0.055526529999963256] and parameters: {'hidden_size': 60, 'num_layers': 3, 'lr': 0.002041647020718277, 'batch_size': 64}.

# %%
print_pareto_front(study)
# Out:
# Pareto-front trials: 8
# ============================================================
# Trial #12  | F1-score: 0.9986 | Inference Time: 47.169 ms
# Parameters: {'hidden_size': 33, 'num_layers': 5, 'lr': 0.001319994226153501, 'batch_size': 64}
# ------------------------------------------------------------
# Trial #16  | F1-score: 0.9946 | Inference Time: 45.437 ms
# Parameters: {'hidden_size': 149, 'num_layers': 3, 'lr': 1.1919481947918725e-05, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #17  | F1-score: 0.9989 | Inference Time: 48.737 ms
# Parameters: {'hidden_size': 102, 'num_layers': 3, 'lr': 0.005280796376895365, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #22  | F1-score: 0.9990 | Inference Time: 53.771 ms
# Parameters: {'hidden_size': 58, 'num_layers': 2, 'lr': 0.0067410742656406975, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #24  | F1-score: 0.9984 | Inference Time: 46.763 ms
# Parameters: {'hidden_size': 96, 'num_layers': 1, 'lr': 0.0006740513796374046, 'batch_size': 32}
# ------------------------------------------------------------
# Trial #27  | F1-score: 0.9976 | Inference Time: 46.732 ms
# Parameters: {'hidden_size': 174, 'num_layers': 3, 'lr': 1.865818136012483e-05, 'batch_size': 32}
# ------------------------------------------------------------
# Trial #33  | F1-score: 0.9994 | Inference Time: 125.398 ms
# Parameters: {'hidden_size': 231, 'num_layers': 4, 'lr': 0.0008435191341743053, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #41  | F1-score: 0.9992 | Inference Time: 56.744 ms
# Parameters: {'hidden_size': 128, 'num_layers': 5, 'lr': 0.007777856590163646, 'batch_size': 32}
# ------------------------------------------------------------

# %% [markdown]
# In cybersecurity systems, achieving high classification accuracy is important, but inference speed is also critical.
#
# A highly accurate model may become impractical if:
#
# - Prediction latency is too high
# - Real-time detection is required
# - Computational resources are limited
#
# The Pareto Front analysis allows selecting architectures that satisfy operational constraints while maintaining strong detection performance.

# %%
plot_pareto_front(study)

# %%
def pareto_dataframe(study):

    rows = []

    for t in study.best_trials:

        rows.append({
            "Trial": t.number,
            "F1-score": round(t.values[0], 4),
            "Inference Time (ms)": round(t.values[1] * 1000, 3),
            "Hidden Size": t.params["hidden_size"],
            "Num Layers": t.params["num_layers"],
            "Learning Rate": t.params["lr"],
            "Batch Size": t.params["batch_size"]
        })

    df = pd.DataFrame(rows)

    return df

# %%
df_pareto = pareto_dataframe(study)

print(df_pareto)
# Out:
#    Trial  F1-score  Inference Time (ms)  Hidden Size  Num Layers  \
# 0     12    0.9986               47.169           33           5
# 1     16    0.9946               45.437          149           3
# 2     17    0.9989               48.737          102           3
# 3     22    0.9990               53.771           58           2
# 4     24    0.9984               46.763           96           1
# 5     27    0.9976               46.732          174           3
# 6     33    0.9994              125.398          231           4
# 7     41    0.9992               56.744          128           5
#
#    Learning Rate  Batch Size
# 0       0.001320          64
# 1       0.000012         128
# 2       0.005281         128
# 3       0.006741         128
# 4       0.000674          32
# 5       0.000019          32
# 6       0.000844         128
# 7       0.007778          32

# %%
df_pareto.to_csv("pareto_balanced_results.csv", index=False)

# %%
best_trial = df_pareto.iloc[3]

# %% [markdown]
# # **4.Train Best Model**

# %%
best_params = best_trial

final_model = build_model(
    hidden_size=int(best_params["Hidden Size"]),
    lr=float(best_params["Learning Rate"]),
    num_layers=int(best_params["Num Layers"])
)

history = final_model.fit(
    X_train,
    y_train,
    batch_size=int(best_params["Batch Size"]),
    epochs=20,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/20
# 196/196 [==============================] - 1s 2ms/step - loss: 0.0325 - accuracy: 0.9924 - val_loss: 0.0098 - val_accuracy: 0.9979
# Epoch 2/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0098 - val_accuracy: 0.9981
# Epoch 3/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0131 - val_accuracy: 0.9966
# Epoch 4/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0060 - val_accuracy: 0.9986
# Epoch 5/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0054 - val_accuracy: 0.9987
# Epoch 6/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0052 - val_accuracy: 0.9992
# Epoch 7/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0053 - val_accuracy: 0.9989
# Epoch 8/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9989
# Epoch 9/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0062 - val_accuracy: 0.9989
# Epoch 10/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0064 - val_accuracy: 0.9987
# Epoch 11/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0090 - val_accuracy: 0.9987
# Epoch 12/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0072 - val_accuracy: 0.9987
# Epoch 13/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.0055 - val_accuracy: 0.9989
# Epoch 14/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0052 - val_accuracy: 0.9994
# Epoch 15/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0056 - val_accuracy: 0.9994
# Epoch 16/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0063 - val_accuracy: 0.9992
# Epoch 17/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0085 - val_accuracy: 0.9987
# Epoch 18/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.9987 - val_loss: 0.0175 - val_accuracy: 0.9973
# Epoch 19/20
# 196/196 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.0087 - val_accuracy: 0.9989
# Epoch 20/20
# 196/196 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0079 - val_accuracy: 0.9994

# %%
# Predictions
y_pred = final_model.predict(X_test, verbose=0)
y_pred = (y_pred > 0.5).astype(int).flatten()

# F1-score
test_f1 = f1_score(y_test, y_pred)



sample = X_test[:1]
times = []
final_model.predict(sample, verbose=0)

for _ in range(100):

    start = time.perf_counter()
    final_model.predict(sample, verbose=0)
    end = time.perf_counter()
    times.append(end - start)

# Average latency in milliseconds
avg_inference_time_ms = np.mean(times) * 1000

# Results
print(f"Test F1-score: {test_f1:.4f}")

print(
    f"Average Inference Time: "
    f"{avg_inference_time_ms:.4f} ms/sample"
)
# Out:
# Test F1-score: 0.9995
# Average Inference Time: 58.6549 ms/sample

# %% [markdown]
# ### **Metrics**

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("AUC:", tf.keras.metrics.AUC()(y_test, y_pred_probs).numpy() )

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9990118705145998
# Precision: 0.9999979200076544
# Recall: 0.9990119388129344
# F1 Score: 0.9995046862501838
# AUC: 0.99972534
#
# Confusion Matrix:
# [[   3911       4]
#  [   1902 1923080]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80      3915
#            1       1.00      1.00      1.00   1924982
#
#     accuracy                           1.00   1928897
#    macro avg       0.84      1.00      0.90   1928897
# weighted avg       1.00      1.00      1.00   1928897

# %%
confusion_matrix_heatmap(y_test, y_pred, save_dir="results/plots", model_name="optuna Optimization MLP", normalize=False)
# Out:
# Confusion matrix saved to:
#  - results\plots\optuna_optimization_mlp_confusion_matrix.png
#  - results\plots\optuna_optimization_mlp_confusion_matrix.pdf

# %%
results = {

    "accuracy": float(
        accuracy_score(y_test, y_pred)
    ),

    "precision": float(
        precision_score(y_test, y_pred)
    ),

    "recall": float(
        recall_score(y_test, y_pred)
    ),

    "f1_score": float(
        f1_score(y_test, y_pred)
    ),

    "auc": float(
        tf.keras.metrics.AUC()(
            y_test,
            y_pred_probs
        ).numpy()
    ),

    "inference_time_ms": avg_inference_time_ms,

    "confusion_matrix": confusion_matrix(
        y_test,
        y_pred
    ).tolist(),

    "classification_report": classification_report(
        y_test,
        y_pred,
        output_dict=True
    )
}

# %% [markdown]
# ### **Export results in json format**

# %%
os.makedirs("results/balanced", exist_ok=True)

# Export path
results_path = os.path.join(
    "results/balanced",
    "evaluation_results_balanced_optuna.json"
)

# Save results
with open(results_path, "w") as f:
    json.dump(
        results,
        f,
        indent=4
    )

print(f"Results exported to: {results_path}")
# Out:
# Results exported to: results/balanced\evaluation_results_balanced_optuna.json
