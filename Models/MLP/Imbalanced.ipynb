# %% [markdown]
# # **Imbalanced: MLP**

# %% [markdown]
# # **Cybersecurity Network Traffic Dataset: Baseline**
#
# This dataset contains **network traffic records used for cybersecurity analysis**, specifically focused on detecting **Distributed Denial of Service (DDoS) and network flooding attacks**.
# Each CSV file represents traffic captured during a **specific attack type or normal network behavior**.
#
#
# The dataset is divided into multiple CSV files, each corresponding to a specific attack category or normal traffic type.
#
# | File | Description |
# |-----|-------------|
# | `DrDoS_DNS.csv` | DNS amplification Distributed Reflection Denial of Service attack traffic |
# | `DrDoS_LDAP.csv` | LDAP reflection DDoS attack traffic |
# | `DrDoS_MSSQL.csv` | MSSQL reflection DDoS attack traffic |
# | `DrDoS_NetBIOS.csv` | NetBIOS reflection DDoS attack traffic |
# | `DrDoS_NTP.csv` | NTP amplification attack traffic |
# | `DrDoS_SNMP.csv` | SNMP reflection DDoS attack traffic |
# | `DrDoS_SSDP.csv` | SSDP reflection DDoS attack traffic |
# | `DrDoS_UDP.csv` | UDP flood distributed denial of service traffic |
# | `Syn.csv` | SYN flood attack traffic |
#
# These attack types are examples of volumetric or reflection-based DDoS attacks, where attackers overwhelm a server or network by generating massive traffic.
#
# For training, we only consider the following CSV files due to limited computational resources. These CSV files were selected because these traffic types are commonly associated with reflection and amplification attacks. In these attacks, the attacker sends spoofed requests to legitimate servers (such as DNS, LDAP, or NTP services). The source IP address is forged to appear as the victim's address. As a result, the legitimate server sends the response to the victim instead of the attacker. Therefore, the analysis will focus on the following datasets:
#
# - **DNS.csv**
# - **LDAP.csv**
# - **NTP.csv**
# - **Syn.csv**

# %% [markdown]
# ### **00 Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)
import seaborn as sns
import time
import json
import os

# %%
def confusion_matrix_heatmap(
    y_true,
    y_pred,
    save_dir,
    model_name="Model",
    normalize=False,
    figsize=(7, 6),
    dpi=600
):
    """
    Generates and saves a publication-quality confusion matrix heatmap.

    Parameters:
    - y_true : array-like
        Ground truth labels.
    - y_pred : array-like
        Predicted labels.
    - model_name : str
        Name used for plot title and export filename.
    - normalize : bool
        If True, displays normalized percentages.
    - figsize : tuple
        Figure size.

    dpi : int
        Export image quality.
    """

    save_dir = os.path.join("results", "plots")
    os.makedirs(save_dir, exist_ok=True)

    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
        fmt = ".2f"
    else:
        fmt = "d"

    # Labels
    labels = ["No Attack", "Attack"]
    plt.style.use("seaborn-v0_8-white")
    fig, ax = plt.subplots(figsize=figsize, dpi=dpi)

    sns.heatmap(
        cm,
        annot=True,
        fmt=fmt,
        cmap="Blues",
        cbar=True,
        square=True,
        linewidths=1,
        linecolor="black",
        xticklabels=labels,
        yticklabels=labels,
        annot_kws={
            "size": 13,
            "weight": "bold"
        },
        ax=ax
    )

    # Titles and labels
    ax.set_title(
        f"{model_name} Confusion Matrix",
        fontsize=16,
        weight="bold",
        pad=15
    )

    ax.set_xlabel(
        "Predicted Label",
        fontsize=13,
        weight="bold"
    )

    ax.set_ylabel(
        "True Label",
        fontsize=13,
        weight="bold"
    )

    # Tick formatting
    ax.tick_params(axis='both', labelsize=11)

    plt.xticks(rotation=0)
    plt.yticks(rotation=0)

    # Improve spacing
    plt.tight_layout()

    # Export paths
    png_path = os.path.join(
        save_dir,
        f"{model_name.lower().replace(' ', '_')}_confusion_matrix.png"
    )

    pdf_path = os.path.join(
        save_dir,
        f"{model_name.lower().replace(' ', '_')}_confusion_matrix.pdf"
    )

    # Save figures
    plt.savefig(png_path, dpi=dpi, bbox_inches="tight")    
    plt.savefig(pdf_path, bbox_inches="tight")
        
    print(f"Confusion matrix saved to:")
    print(f" - {png_path}")
    print(f" - {pdf_path}")

    plt.show()

# %% [markdown]
# ### **01 Load Dataset**

# %% [markdown]
# The preprocessed dataset generated in the `02_Preprocessed.ipynb` notebook was loaded for the training phase.
#
# After loading the dataset:
#
# 1. The target variable (`Label`) was separated from the feature set.
# 2. The label column was removed from the input features to avoid data leakage during training.
# 3. Feature scaling was applied using `StandardScaler`.
#
# Standardization was performed to normalize the feature distributions and improve neural network convergence during training.
#
# This preprocessing step ensures that all numerical features contribute proportionally during optimization and model training.

# %%
path = r"C:\\Users\\Ale\\Documents\\NN-Labs\\Midterm\\Optuna-MLP-DDoS-detection\\Data_Preprocessing\\imbalanced_data"
train_path = f"{path}/train.csv"
val_path = f"{path}/val.csv"
test_path = f"{path}/test.csv"

# %%
train = pd.read_csv(train_path)
val = pd.read_csv(val_path)
test = pd.read_csv(test_path)

# %%
# Train
X_train = train.drop(["Label", "source_dataset"], axis=1)
y_train = train["Label"]

# Validation
X_val = val.drop(["Label", "source_dataset"], axis=1)
y_val = val["Label"]

# Test
X_test = test.drop(["Label", "source_dataset"], axis=1)
y_test = test["Label"]

# %%
X_train = X_train.astype('float32')
X_val   = X_val.astype('float32')
X_test  = X_test.astype('float32')

# %%
print(X_train.shape)
print(X_train.dtypes)
print(X_train.info())
# Out:
# (6172467, 63)
# Unnamed: 0          float32
# Source Port         float32
# Destination Port    float32
# Protocol            float32
# Flow Duration       float32
#                      ...
# Idle Mean           float32
# Idle Std            float32
# Idle Max            float32
# Idle Min            float32
# Inbound             float32
# Length: 63, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6172467 entries, 0 to 6172466
# Data columns (total 63 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Unnamed: 0                   float32
#  1   Source Port                  float32
#  2   Destination Port             float32
#  3   Protocol                     float32
#  4   Flow Duration                float32
#  5   Total Fwd Packets            float32
#  6   Total Backward Packets       float32
#  7   Total Length of Fwd Packets  float32
#  8   Total Length of Bwd Packets  float32
#  9   Fwd Packet Length Max        float32
#  10  Fwd Packet Length Min        float32
#  11  Fwd Packet Length Mean       float32
#  12  Fwd Packet Length Std        float32
#  13  Bwd Packet Length Max        float32
#  14  Bwd Packet Length Min        float32
#  15  Bwd Packet Length Mean       float32
#  16  Bwd Packet Length Std        float32
#  17  Flow Bytes/s                 float32
#  18  Flow Packets/s               float32
#  19  Flow IAT Mean                float32
#  20  Flow IAT Std                 float32
#  21  Flow IAT Max                 float32
#  22  Flow IAT Min                 float32
#  23  Fwd IAT Total                float32
#  24  Fwd IAT Mean                 float32
#  25  Fwd IAT Std                  float32
#  26  Fwd IAT Max                  float32
#  27  Fwd IAT Min                  float32
#  28  Bwd IAT Total                float32
#  29  Bwd IAT Mean                 float32
#  30  Bwd IAT Std                  float32
#  31  Bwd IAT Max                  float32
#  32  Bwd IAT Min                  float32
#  33  Fwd PSH Flags                float32
#  34  Fwd Header Length            float32
#  35  Bwd Header Length            float32
#  36  Fwd Packets/s                float32
#  37  Bwd Packets/s                float32
#  38  Min Packet Length            float32
#  39  Max Packet Length            float32
#  40  Packet Length Mean           float32
#  41  Packet Length Std            float32
#  42  Packet Length Variance       float32
#  43  SYN Flag Count               float32
#  44  ACK Flag Count               float32
#  45  URG Flag Count               float32
#  46  CWE Flag Count               float32
#  47  Down/Up Ratio                float32
#  48  Average Packet Size          float32
#  49  Avg Bwd Segment Size         float32
#  50  Init_Win_bytes_forward       float32
#  51  Init_Win_bytes_backward      float32
#  52  act_data_pkt_fwd             float32
#  53  min_seg_size_forward         float32
#  54  Active Mean                  float32
#  55  Active Std                   float32
#  56  Active Max                   float32
#  57  Active Min                   float32
#  58  Idle Mean                    float32
#  59  Idle Std                     float32
#  60  Idle Max                     float32
#  61  Idle Min                     float32
#  62  Inbound                      float32
# dtypes: float32(63)
# memory usage: 1.4 GB
# None

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **1. Baseline Model**
#
# A baseline neural network model was defined in order to establish a reference point for comparison with the Optuna multi-objective optimization process.
#
# This baseline architecture was intentionally designed as a simple feedforward neural network with a fixed structure. The objective is to evaluate how much performance improvement can be achieved after hyperparameter optimization.
#
# The model consists of:
#
# - An input layer connected to:
#   - A hidden layer with 32 neurons
#   - A second hidden layer with 16 neurons
# - A final output layer using a sigmoid activation function for binary classification
#
# The sigmoid activation function was selected because the problem is formulated as a binary classification task, where the model predicts whether the network traffic corresponds to normal behavior or an attack.
#
# The baseline architecture serves as the reference model against which the optimized Optuna-generated architectures are compared in terms of:
#
# - F1-score
# - Prediction time
# - Overall classification performance

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def create_baseline_model(input_dim):

    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(32, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            keras.metrics.AUC(name="auc")
        ]
    )

    return model

# %% [markdown]
# ## **Baseline Architecture**
#
# | **Layer** | **Configuration** |
# |---|---|
# | Hidden Layer 1 | 32 neurons |
# | Hidden Layer 2 | 16 neurons |
# | Output Layer | 1 neuron + Sigmoid |

# %%
model = create_baseline_model(X_train.shape[1])
model.summary()
# Out:
# Model: "sequential_51"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_210 (Dense)           (None, 32)                2048
#
#  dense_211 (Dense)           (None, 16)                528
#
#  dense_212 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 2593 (10.13 KB)
# Trainable params: 2593 (10.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=256,
    verbose=1
)
# Out:
# Epoch 1/20
# 24112/24112 [==============================] - 39s 2ms/step - loss: 0.0013 - accuracy: 0.9999 - auc: 0.9943 - val_loss: 1.9899e-04 - val_accuracy: 1.0000 - val_auc: 0.9973
# Epoch 2/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 1.6726e-04 - accuracy: 1.0000 - auc: 0.9979 - val_loss: 9.5694e-05 - val_accuracy: 1.0000 - val_auc: 0.9981
# Epoch 3/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 1.8527e-04 - accuracy: 1.0000 - auc: 0.9982 - val_loss: 1.0199e-04 - val_accuracy: 1.0000 - val_auc: 0.9979
# Epoch 4/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 1.0545e-04 - accuracy: 1.0000 - auc: 0.9985 - val_loss: 9.6761e-05 - val_accuracy: 1.0000 - val_auc: 0.9981
# Epoch 5/20
# 24112/24112 [==============================] - 36s 2ms/step - loss: 1.0331e-04 - accuracy: 1.0000 - auc: 0.9987 - val_loss: 1.0752e-04 - val_accuracy: 1.0000 - val_auc: 0.9982
# Epoch 6/20
# 24112/24112 [==============================] - 36s 1ms/step - loss: 1.9020e-04 - accuracy: 1.0000 - auc: 0.9989 - val_loss: 7.2107e-05 - val_accuracy: 1.0000 - val_auc: 0.9990
# Epoch 7/20
# 24112/24112 [==============================] - 36s 1ms/step - loss: 1.6917e-04 - accuracy: 1.0000 - auc: 0.9990 - val_loss: 8.8504e-05 - val_accuracy: 1.0000 - val_auc: 0.9992
# Epoch 8/20
# 24112/24112 [==============================] - 36s 1ms/step - loss: 7.5589e-05 - accuracy: 1.0000 - auc: 0.9988 - val_loss: 8.2594e-05 - val_accuracy: 1.0000 - val_auc: 0.9990
# Epoch 9/20
# 24112/24112 [==============================] - 36s 2ms/step - loss: 9.8285e-05 - accuracy: 1.0000 - auc: 0.9990 - val_loss: 8.4887e-05 - val_accuracy: 1.0000 - val_auc: 0.9989
# Epoch 10/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 6.4410e-05 - accuracy: 1.0000 - auc: 0.9992 - val_loss: 9.6299e-05 - val_accuracy: 1.0000 - val_auc: 0.9987
# Epoch 11/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 9.4349e-05 - accuracy: 1.0000 - auc: 0.9990 - val_loss: 1.1705e-04 - val_accuracy: 1.0000 - val_auc: 0.9987
# Epoch 12/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 1.5922e-04 - accuracy: 1.0000 - auc: 0.9989 - val_loss: 5.9256e-05 - val_accuracy: 1.0000 - val_auc: 0.9992
# Epoch 13/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 7.7204e-05 - accuracy: 1.0000 - auc: 0.9990 - val_loss: 1.3992e-04 - val_accuracy: 1.0000 - val_auc: 0.9994
# Epoch 14/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 6.7823e-05 - accuracy: 1.0000 - auc: 0.9990 - val_loss: 6.6378e-05 - val_accuracy: 1.0000 - val_auc: 0.9992
# Epoch 15/20
# 24112/24112 [==============================] - 36s 1ms/step - loss: 9.4635e-05 - accuracy: 1.0000 - auc: 0.9992 - val_loss: 1.5519e-04 - val_accuracy: 1.0000 - val_auc: 0.9990
# Epoch 16/20
# 24112/24112 [==============================] - 36s 2ms/step - loss: 6.0369e-05 - accuracy: 1.0000 - auc: 0.9993 - val_loss: 9.9146e-05 - val_accuracy: 1.0000 - val_auc: 0.9990
# Epoch 17/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 2.1188e-04 - accuracy: 1.0000 - auc: 0.9991 - val_loss: 8.8116e-05 - val_accuracy: 1.0000 - val_auc: 0.9992
# Epoch 18/20
# 24112/24112 [==============================] - 36s 2ms/step - loss: 6.0534e-05 - accuracy: 1.0000 - auc: 0.9992 - val_loss: 1.3652e-04 - val_accuracy: 1.0000 - val_auc: 0.9989
# Epoch 19/20
# 24112/24112 [==============================] - 36s 2ms/step - loss: 2.7806e-04 - accuracy: 1.0000 - auc: 0.9993 - val_loss: 1.6667e-04 - val_accuracy: 1.0000 - val_auc: 0.9971
# Epoch 20/20
# 24112/24112 [==============================] - 37s 2ms/step - loss: 5.2920e-05 - accuracy: 1.0000 - auc: 0.9992 - val_loss: 1.0077e-04 - val_accuracy: 1.0000 - val_auc: 0.9986

# %% [markdown]
# Proving with testing and time measurement

# %%
times = []
# Warmup
model.predict(
    X_test[:1],
    verbose=0
)

for _ in range(100):
    start = time.perf_counter()
    model.predict(
        X_test[:1],
        verbose=0
    )

    end = time.perf_counter()
    times.append(end - start)

# Average latency in milliseconds
baseline_inference_time_ms = float(
    np.mean(times) * 1000
)

# %%
y_pred_probs = model.predict(
    X_test,
    batch_size=4096,
    verbose=1
)

y_pred = (y_pred_probs > 0.5).astype(int).flatten()

print(
    f"Baseline Inference Time: "
    f"{baseline_inference_time_ms:.4f} ms/sample"
)
# Out:
# 471/471 [==============================] - 1s 1ms/step
# Baseline Inference Time: 64.7182 ms/sample

# %% [markdown]
# ### **Metrics**

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("AUC:", tf.keras.metrics.AUC()(y_test, y_pred_probs).numpy() )

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9999906682420057
# Precision: 0.9999916882944172
# Recall: 0.999998961029246
# F1 Score: 0.9999953246486084
# AUC: 0.9988505
#
# Confusion Matrix:
# [[   3899      16]
#  [      2 1924980]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3915
#            1       1.00      1.00      1.00   1924982
#
#     accuracy                           1.00   1928897
#    macro avg       1.00      1.00      1.00   1928897
# weighted avg       1.00      1.00      1.00   1928897

# %% [markdown]
# ### **Export Results in json format**

# %%
results = {

    "accuracy": float(
        accuracy_score(y_test, y_pred)
    ),

    "precision": float(
        precision_score(y_test, y_pred)
    ),

    "recall": float(
        recall_score(y_test, y_pred)
    ),

    "f1_score": float(
        f1_score(y_test, y_pred)
    ),

    "auc": float(
        tf.keras.metrics.AUC()(
            y_test,
            y_pred
        ).numpy()
    ),

    "inference_time_ms": baseline_inference_time_ms,

    "confusion_matrix": confusion_matrix(
        y_test,
        y_pred
    ).tolist(),

    "classification_report": classification_report(
        y_test,
        y_pred,
        output_dict=True
    )
}

# %%
os.makedirs("results/imbalanced", exist_ok=True)

with open("results/imbalanced/evaluation_results_imbalanced_baseline.json", "w") as f:

    json.dump(
        results,
        f,
        indent=4
    )

print("Results exported to results/imbalanced/evaluation_results_imbalanced_baseline.json")
# Out:
# Results exported to results/imbalanced/evaluation_results_imbalanced_baseline.json

# %% [markdown]
# ### **Confusion Matrix**

# %%
confusion_matrix_heatmap(y_test, y_pred, save_dir="results/imbalanced", model_name="Imbalanced Baseline MLP",)
# Out:
# Confusion matrix saved to:
#  - results\plots\imbalanced_baseline_mlp_confusion_matrix.png
#  - results\plots\imbalanced_baseline_mlp_confusion_matrix.pdf

# %% [markdown]
# # **2. Optuna Optimization**
#
# To improve the performance of the baseline neural network, a multi-objective hyperparameter optimization process was implemented using **Optuna**. Optuna is an automatic hyperparameter optimization framework designed to efficiently explore large search spaces and identify optimal model configurations.
#
# In this project, Optuna was used to optimize the neural network architecture and training parameters while simultaneously considering two objectives:
#
# - Maximize the F1-score
# - Minimize prediction time
#
# This approach allows the identification of models that not only achieve high classification performance but also maintain low inference latency for real-time cybersecurity applications.

# %%
#import sys
#!{sys.executable} -m pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (6.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from plotly) (2.18.1)
# Requirement already satisfied: packaging in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from plotly) (26.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import sys
#!{sys.executable} -m pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (4.8.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: tomli in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (2.4.1)
# Requirement already satisfied: greenlet>=1 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: colorama in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\ale\documents\nn-labs\.venv\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import numpy as np
import optuna
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### **Optimization Strategy**
#
# The study was configured as a **multi-objective optimization problem**, where each trial generates a different neural network configuration.
#
# For every trial, Optuna evaluates:
#
# 1. Neural network architecture
# 2. Learning rate
# 3. Batch size
# 4. Number of hidden layers
# 5. Hidden layer dimensions
#
# The resulting model is then trained and evaluated using the validation dataset.
#
# The following hyperparameters were explored during optimization:
#
# | Hyperparameter | Search Range |
# |---|---|
# | Hidden layer size | 32 → 256 |
# | Number of hidden layers | 1 → 5 |
# | Learning rate | 1e-5 → 1e-2 |
# | Batch size | 32, 64, 128 |

# %%
RANDOM_STATE = 42
N_TRIALS = 100
N_RUNS_TIMING = 10

# Hidden layer size range
HIDDEN_SIZE_MIN = 32
HIDDEN_SIZE_MAX = 256

# Number of hidden layers
NUM_LAYERS_MIN = 1
NUM_LAYERS_MAX = 5

# Learning rate range
LR_MIN = 1e-5
LR_MAX = 1e-2

# Batch size options
BATCH_SIZES = [32, 64, 128]

# Optimization directions
DIRECTIONS = ["maximize", "minimize"]

# %% [markdown]
# ### **Multi-Objective Optimization**
#
# The optimization process simultaneously evaluates:
#
# | Objective | Goal |
# |---|---|
# | F1-score | Maximize |
# | Prediction time | Minimize |
#
# Because these objectives are conflicting, Optuna generates a **Pareto Front**, which contains the set of optimal trade-off solutions.
#
# Some models may achieve:
#
# - Higher classification accuracy with slower inference
# - Faster prediction speed with slightly lower performance
#
# This methodology allows selecting models according to system requirements and computational constraints.

# %%
from sklearn.model_selection import train_test_split

# Keep only 20% of the training set for Optuna
X_train_optuna, _, y_train_optuna, _ = train_test_split(
    X_train,
    y_train,
    train_size=0.10,
    stratify=y_train,
    random_state=42
)

print(f"Original train size: {len(X_train):,}")
print(f"Optuna train size: {len(X_train_optuna):,}")
# Out:
# Original train size: 6,172,467
# Optuna train size: 617,246

# %%
X_val_optuna, _, y_val_optuna, _ = train_test_split(
    X_val,
    y_val,
    train_size=0.10,
    stratify=y_val,
    random_state=42
)

print(f"Original val size: {len(X_val):,}")
print(f"Optuna val size: {len(X_val_optuna):,}")
# Out:
# Original val size: 1,543,117
# Optuna val size: 154,311

# %%
def build_model(hidden_size, lr, num_layers):

    model = keras.Sequential()
    # Input layer + first hidden layer
    model.add(
        layers.Dense(
            hidden_size,
            activation="relu",
            input_shape=(X_train_optuna.shape[1],)
        )
    )
    # Additional hidden layers
    current_size = hidden_size
    for _ in range(num_layers - 1):
        # Optional progressive reduction
        current_size = max(current_size // 2, 16)
        model.add(
            layers.Dense(
                current_size,
                activation="relu"
            )
        )
    # Output layer
    model.add(
        layers.Dense(1, activation="sigmoid")
    )
    # Optimizer
    optimizer = keras.optimizers.Adam(
        learning_rate=lr
    )
    # Compile model
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
def train_and_evaluate(model, batch_size):

    history = model.fit(
        X_train_optuna,
        y_train_optuna,
        validation_data=(X_val_optuna, y_val_optuna),
        epochs=10,
        batch_size=batch_size,
        verbose=0
    )

    # Predictions
    y_pred = model.predict(X_val_optuna, verbose=0)

    # Convert probabilities to binary labels
    y_pred = (y_pred > 0.5).astype(int).flatten()

    # F1-score
    f1 = f1_score(y_val_optuna, y_pred)

    # Validation loss
    val_loss = history.history["val_loss"][-1]

    return val_loss, f1

# %% [markdown]
# ### **Prediction Time Evaluation**
#
# Inference latency was incorporated as a second optimization objective in order to evaluate real-time applicability.
#
# Prediction time was measured multiple times to reduce noise and variability:
# The average prediction time across all runs was used during optimization.

# %%
import time
import numpy as np

def measure_inference_time(model, X_val_optuna, n_runs=N_RUNS_TIMING):
    # Single sample
    sample = X_val_optuna[:1]
    times = []

    # Warmup
    model.predict(sample, verbose=0)

    for _ in range(n_runs):
        start = time.perf_counter()
        model.predict(sample, verbose=0)
        end = time.perf_counter()
        times.append(end - start)

    return float(np.mean(times))

# %%
def objective(trial):

    # Hyperparameters
    hidden_size = trial.suggest_int(
        "hidden_size",
        HIDDEN_SIZE_MIN,
        HIDDEN_SIZE_MAX
    )

    num_layers = trial.suggest_int(
        "num_layers",
        NUM_LAYERS_MIN,
        NUM_LAYERS_MAX
    )

    lr = trial.suggest_float(
        "lr",
        LR_MIN,
        LR_MAX,
        log=True
    )

    batch_size = trial.suggest_categorical(
        "batch_size",
        BATCH_SIZES
    )

    # Build model
    model = build_model(
        hidden_size=hidden_size,
        lr=lr,
        num_layers=num_layers
    )

    # Train and evaluate
    val_loss, f1 = train_and_evaluate(
        model,
        batch_size
    )

    # Measure inference speed
    inference_time = measure_inference_time(
        model,
        X_val_optuna
    )

    # Multi-objective optimization
    return f1, inference_time

# %%
def create_study():

    study = optuna.create_study(
        directions=DIRECTIONS,
        sampler=optuna.samplers.NSGAIISampler(seed=RANDOM_STATE)
    )

    return study

# %% [markdown]
# ### **Pareto Front Analysis**
# In this project, the optimization process simultaneously attempts to:
#
# - Maximize the F1-score
# - Minimize prediction time
#
# These objectives are inherently conflicting because more complex neural network architectures may achieve higher classification performance while also increasing computational cost and inference latency.
# To analyze this trade-off, Optuna generates a **Pareto Front**.
#
# A Pareto Front is the set of optimal solutions in a multi-objective optimization problem.
# A solution belongs to the Pareto Front if:
#
# - No other solution improves one objective without worsening the other.
# - Its F1-score cannot be improved without increasing prediction time.
# - Its prediction time cannot be reduced without decreasing F1-score.
#
# These solutions represent the best trade-offs discovered during optimization.
#
# ###  **Pareto Dominance**
#
# A model is said to dominate another model if:
#
# - It achieves equal or better performance in all objectives
# - And strictly better performance in at least one objective
#
# The Pareto Front provides multiple optimal candidate models rather than a single “best” solution.
#
# This allows selecting models depending on system requirements.
# During Optuna optimization:
#
# - Each trial generates a different neural network architecture.
# - Each model is evaluated using:
#   - F1-score
#   - Prediction time
#
# After all trials are completed, Optuna identifies the subset of non-dominated solutions.
#
# These solutions form the Pareto Front.
#
# The Pareto-optimal models represent the best balance between:
#
# - Detection capability
# - Computational efficiency

# %%
def print_pareto_front(study):

    pareto_trials = study.best_trials
    print(f"\nPareto-front trials: {len(pareto_trials)}")
    print("=" * 60)
    for t in pareto_trials:

        f1_score_val = t.values[0]
        inf_time_ms = t.values[1] * 1000
        print(
            f"Trial #{t.number:<3} | "
            f"F1-score: {f1_score_val:.4f} | "
            f"Inference Time: {inf_time_ms:.3f} ms"
        )
        print(f"Parameters: {t.params}")
        print("-" * 60)

# %%
def plot_pareto_front(study, save_path="pareto_imbalance"):
    if save_path not in os.listdir("results/imbalance"):
        os.makedirs(save_path, exist_ok=True)
    pareto_trials = study.best_trials

    f1_scores = [t.values[0] for t in pareto_trials]

    inference_times = [
        t.values[1] * 1000
        for t in pareto_trials
    ]

    plt.figure(figsize=(7, 5), dpi=300)

    plt.scatter(
        inference_times,
        f1_scores,
        s=80,
        alpha=0.8
    )

    # Annotate each point with trial number
    for i, t in enumerate(pareto_trials):

        plt.annotate(
            f"T{t.number}",
            (inference_times[i], f1_scores[i]),
            textcoords="offset points",
            xytext=(5, 5),
            fontsize=9
        )

    plt.xlabel("Inference Time (ms)", fontsize=12)
    plt.ylabel("F1-score", fontsize=12)

    plt.title(
        "Pareto Front for Multi-Objective Optimization",
        fontsize=14,
        weight='bold'
    )

    plt.grid(True)

    plt.tight_layout()

    # Save publication-quality figure
    if save_path:
        plt.savefig(
            save_path,
            dpi=300,
            bbox_inches='tight'
        )

    plt.show()

# %% [markdown]
# ### **Training Workflow**
# Unlike the baseline model, the Optuna architecture is not fixed.
# The number of layers and neurons is dynamically generated according to the sampled hyperparameters.
# This allows the optimizer to explore multiple architectural combinations and identify efficient configurations.
#
# For each Optuna trial:
#
# 1. A neural network architecture is generated dynamically.
# 2. Hyperparameters are sampled from the search space.
# 3. The model is trained using the balanced training dataset.
# 4. Validation metrics are computed.
# 5. Prediction time is measured multiple times.
# 6. Both objectives are returned to the optimizer.
#
# The optimization process continues for a total of 100 trials.

# %%
study = create_study()
# Out:
# [I 2026-05-31 05:34:41,041] A new study created in memory with name: no-name-5ad86122-232e-4ceb-88d7-1ccb548c9cb9

# %%
study.optimize(objective, n_trials=50)
# Out:
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Ale\Documents\NN-Labs\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# [I 2026-05-31 05:39:16,193] Trial 0 finished with values: [0.9999350615616396, 0.05899475999995048] and parameters: {'hidden_size': 116, 'num_layers': 5, 'lr': 0.001570297088405539, 'batch_size': 32}.
# [I 2026-05-31 05:40:28,583] Trial 1 finished with values: [0.9999318201740858, 0.04824122000004536] and parameters: {'hidden_size': 45, 'num_layers': 5, 'lr': 0.0006358358856676254, 'batch_size': 128}.
# [I 2026-05-31 05:41:49,916] Trial 2 finished with values: [0.9999642849025789, 0.057132930000011586] and parameters: {'hidden_size': 219, 'num_layers': 2, 'lr': 3.511356313970405e-05, 'batch_size': 128}.
# [I 2026-05-31 05:43:04,625] Trial 3 finished with values: [0.9999772722107321, 0.0565644999999904] and parameters: {'hidden_size': 129, 'num_layers': 2, 'lr': 0.000684792009557478, 'batch_size': 128}.
# [I 2026-05-31 05:45:23,089] Trial 4 finished with values: [0.9999805192275224, 0.06029811999994763] and parameters: {'hidden_size': 134, 'num_layers': 4, 'lr': 3.972110727381908e-05, 'batch_size': 64}.
# [I 2026-05-31 05:47:28,057] Trial 5 finished with values: [0.9999383110874457, 0.057928339999989475] and parameters: {'hidden_size': 168, 'num_layers': 1, 'lr': 1.5673095467235405e-05, 'batch_size': 64}.
# [I 2026-05-31 05:48:35,752] Trial 6 finished with values: [0.9999740254680286, 0.058098899999981767] and parameters: {'hidden_size': 100, 'num_layers': 1, 'lr': 0.0011290133559092666, 'batch_size': 128}.
# [I 2026-05-31 05:53:01,949] Trial 7 finished with values: [0.9999610379490377, 0.05891458999999486] and parameters: {'hidden_size': 39, 'num_layers': 5, 'lr': 5.9750279999602906e-05, 'batch_size': 32}.
# [I 2026-05-31 05:55:10,034] Trial 8 finished with values: [0.9999610376960291, 0.057614230000035606] and parameters: {'hidden_size': 155, 'num_layers': 1, 'lr': 0.008105016126411584, 'batch_size': 64}.
# [I 2026-05-31 05:56:39,651] Trial 9 finished with values: [0.9999480502613721, 0.061181059999989885] and parameters: {'hidden_size': 166, 'num_layers': 5, 'lr': 1.8427970406864546e-05, 'batch_size': 128}.
# [I 2026-05-31 05:57:53,743] Trial 10 finished with values: [0.9999707783669003, 0.06022939999998016] and parameters: {'hidden_size': 119, 'num_layers': 2, 'lr': 0.003063462210622081, 'batch_size': 128}.
# [I 2026-05-31 06:02:20,032] Trial 11 finished with values: [0.9999155783854691, 0.05835244000004423] and parameters: {'hidden_size': 63, 'num_layers': 5, 'lr': 1.6736010167825783e-05, 'batch_size': 32}.
# [I 2026-05-31 06:04:39,002] Trial 12 finished with values: [0.999967532256703, 0.06255758000002061] and parameters: {'hidden_size': 33, 'num_layers': 5, 'lr': 0.001319994226153501, 'batch_size': 64}.
# [I 2026-05-31 06:08:37,310] Trial 13 finished with values: [0.999967531624198, 0.061017679999986286] and parameters: {'hidden_size': 112, 'num_layers': 1, 'lr': 0.0038842777547031426, 'batch_size': 32}.
# [I 2026-05-31 06:10:48,358] Trial 14 finished with values: [0.9999805191010215, 0.05792365999991489] and parameters: {'hidden_size': 101, 'num_layers': 2, 'lr': 0.0015446089075047066, 'batch_size': 64}.
# [I 2026-05-31 06:12:59,750] Trial 15 finished with values: [0.9999707783669003, 0.05824285999983658] and parameters: {'hidden_size': 58, 'num_layers': 4, 'lr': 0.0019158219548093154, 'batch_size': 64}.
# [I 2026-05-31 06:14:21,885] Trial 16 finished with values: [0.9999577909744116, 0.05955899999999019] and parameters: {'hidden_size': 149, 'num_layers': 3, 'lr': 1.1919481947918725e-05, 'batch_size': 128}.
# [I 2026-05-31 06:15:36,246] Trial 17 finished with values: [0.9995452478399273, 0.05860460000008061] and parameters: {'hidden_size': 102, 'num_layers': 3, 'lr': 0.005280796376895365, 'batch_size': 128}.
# [I 2026-05-31 06:17:39,986] Trial 18 finished with values: [0.999967531624198, 0.05809034000003521] and parameters: {'hidden_size': 83, 'num_layers': 1, 'lr': 7.40038575908737e-05, 'batch_size': 64}.
# [I 2026-05-31 06:20:15,113] Trial 19 finished with values: [0.9995647485285902, 0.057811219999939566] and parameters: {'hidden_size': 174, 'num_layers': 5, 'lr': 0.0025764174425233167, 'batch_size': 64}.
# [I 2026-05-31 06:21:48,156] Trial 20 finished with values: [0.9999740252993584, 0.05754921000007016] and parameters: {'hidden_size': 213, 'num_layers': 5, 'lr': 8.995191735587162e-05, 'batch_size': 128}.
# [I 2026-05-31 06:26:35,331] Trial 21 finished with values: [0.9999740256366966, 0.0636095300001216] and parameters: {'hidden_size': 216, 'num_layers': 5, 'lr': 1.0491954332267901e-05, 'batch_size': 32}.
# [I 2026-05-31 06:27:43,357] Trial 22 finished with values: [0.9997077067974408, 0.05900262000004659] and parameters: {'hidden_size': 58, 'num_layers': 2, 'lr': 0.0067410742656406975, 'batch_size': 128}.
# [I 2026-05-31 06:30:07,608] Trial 23 finished with values: [0.9989847847451745, 0.059397009999975124] and parameters: {'hidden_size': 113, 'num_layers': 5, 'lr': 0.007715105777813051, 'batch_size': 64}.
# [I 2026-05-31 06:34:14,271] Trial 24 finished with values: [0.9999805191010215, 0.05894684000004417] and parameters: {'hidden_size': 96, 'num_layers': 1, 'lr': 0.0006740513796374046, 'batch_size': 32}.
# [I 2026-05-31 06:36:39,562] Trial 25 finished with values: [0.999967531624198, 0.05738215999990644] and parameters: {'hidden_size': 236, 'num_layers': 2, 'lr': 2.7207248059486674e-05, 'batch_size': 64}.
# [I 2026-05-31 06:41:12,644] Trial 26 finished with values: [0.9999805192275224, 0.05812701000004381] and parameters: {'hidden_size': 183, 'num_layers': 4, 'lr': 5.163124910488014e-05, 'batch_size': 32}.
# [I 2026-05-31 06:45:35,243] Trial 27 finished with values: [0.999967531624198, 0.05917152999982136] and parameters: {'hidden_size': 174, 'num_layers': 3, 'lr': 1.865818136012483e-05, 'batch_size': 32}.
# [I 2026-05-31 06:47:43,238] Trial 28 finished with values: [0.9999772723583175, 0.058397929999864574] and parameters: {'hidden_size': 41, 'num_layers': 3, 'lr': 0.001078184503512226, 'batch_size': 64}.
# [I 2026-05-31 06:49:51,869] Trial 29 finished with values: [0.9999740252993584, 0.05943552999979147] and parameters: {'hidden_size': 177, 'num_layers': 1, 'lr': 0.0011825328508422654, 'batch_size': 64}.
# [I 2026-05-31 06:53:51,888] Trial 30 finished with values: [0.9999707785566555, 0.05772990999967078] and parameters: {'hidden_size': 108, 'num_layers': 1, 'lr': 0.0059440281134109305, 'batch_size': 32}.
# [I 2026-05-31 06:55:19,526] Trial 31 finished with values: [0.999957792618903, 0.05778064000014638] and parameters: {'hidden_size': 215, 'num_layers': 3, 'lr': 0.00038810723164094845, 'batch_size': 128}.
# [I 2026-05-31 06:56:55,929] Trial 32 finished with values: [0.9999772722107321, 0.0618142699998316] and parameters: {'hidden_size': 234, 'num_layers': 4, 'lr': 0.00010401341922663452, 'batch_size': 128}.
# [I 2026-05-31 06:58:28,972] Trial 33 finished with values: [0.9999740254680286, 0.05903522999988127] and parameters: {'hidden_size': 231, 'num_layers': 4, 'lr': 0.0008435191341743053, 'batch_size': 128}.
# [I 2026-05-31 07:02:27,222] Trial 34 finished with values: [0.9999642849025789, 0.05825868999991144] and parameters: {'hidden_size': 168, 'num_layers': 1, 'lr': 2.015647705936502e-05, 'batch_size': 32}.
# [I 2026-05-31 07:04:49,442] Trial 35 finished with values: [0.9999707785566555, 0.05893790000027366] and parameters: {'hidden_size': 155, 'num_layers': 4, 'lr': 0.0009034076805537766, 'batch_size': 64}.
# [I 2026-05-31 07:09:10,604] Trial 36 finished with values: [0.9999642849025789, 0.06176049000014246] and parameters: {'hidden_size': 105, 'num_layers': 4, 'lr': 0.0008889937283707153, 'batch_size': 32}.
# [I 2026-05-31 07:11:21,365] Trial 37 finished with values: [0.999964284670656, 0.06016237999983787] and parameters: {'hidden_size': 53, 'num_layers': 2, 'lr': 6.246073681318086e-05, 'batch_size': 64}.
# [I 2026-05-31 07:13:56,295] Trial 38 finished with values: [0.9999512963293666, 0.058201519999875016] and parameters: {'hidden_size': 232, 'num_layers': 4, 'lr': 0.0024234491447023164, 'batch_size': 64}.
# [I 2026-05-31 07:16:10,800] Trial 39 finished with values: [0.9999707787464083, 0.057841999999982366] and parameters: {'hidden_size': 75, 'num_layers': 4, 'lr': 6.955319544158292e-05, 'batch_size': 64}.
# [I 2026-05-31 07:17:50,120] Trial 40 finished with values: [0.999142116243249, 0.05851589999983844] and parameters: {'hidden_size': 243, 'num_layers': 5, 'lr': 0.005553837526912238, 'batch_size': 128}.
# [I 2026-05-31 07:22:25,116] Trial 41 finished with values: [0.9995550026472471, 0.05905434999986028] and parameters: {'hidden_size': 128, 'num_layers': 5, 'lr': 0.007777856590163646, 'batch_size': 32}.
# [I 2026-05-31 07:24:44,055] Trial 42 finished with values: [0.999967532256703, 0.05775750000002518] and parameters: {'hidden_size': 223, 'num_layers': 2, 'lr': 3.22461774864237e-05, 'batch_size': 64}.
# [I 2026-05-31 07:28:41,933] Trial 43 finished with values: [0.9999707783669003, 0.05825970999976562] and parameters: {'hidden_size': 160, 'num_layers': 1, 'lr': 0.0006998769331752384, 'batch_size': 32}.
# [I 2026-05-31 07:33:22,945] Trial 44 finished with values: [0.9998116528437173, 0.05988878000025579] and parameters: {'hidden_size': 229, 'num_layers': 4, 'lr': 0.0012332389221028, 'batch_size': 32}.
# [I 2026-05-31 07:38:11,329] Trial 45 finished with values: [0.9989847847451745, 0.06113490999996429] and parameters: {'hidden_size': 214, 'num_layers': 5, 'lr': 0.003992242886631504, 'batch_size': 32}.
# [I 2026-05-31 07:40:44,728] Trial 46 finished with values: [0.9999772722107321, 0.05763877000008506] and parameters: {'hidden_size': 211, 'num_layers': 4, 'lr': 0.0012761467881730222, 'batch_size': 64}.
# [I 2026-05-31 07:41:50,863] Trial 47 finished with values: [0.9999805191010215, 0.05788036999983888] and parameters: {'hidden_size': 116, 'num_layers': 1, 'lr': 0.0005430507564500919, 'batch_size': 128}.
# [I 2026-05-31 07:44:06,263] Trial 48 finished with values: [0.9999545445690501, 0.058219399999507] and parameters: {'hidden_size': 96, 'num_layers': 3, 'lr': 1.2345274466024455e-05, 'batch_size': 64}.
# [I 2026-05-31 07:46:13,858] Trial 49 finished with values: [0.9999642858302408, 0.05854011999999784] and parameters: {'hidden_size': 60, 'num_layers': 3, 'lr': 0.002041647020718277, 'batch_size': 64}.

# %%
print_pareto_front(study)
# Out:
# Pareto-front trials: 4
# ============================================================
# Trial #1   | F1-score: 0.9999 | Inference Time: 48.241 ms
# Parameters: {'hidden_size': 45, 'num_layers': 5, 'lr': 0.0006358358856676254, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #3   | F1-score: 1.0000 | Inference Time: 56.564 ms
# Parameters: {'hidden_size': 129, 'num_layers': 2, 'lr': 0.000684792009557478, 'batch_size': 128}
# ------------------------------------------------------------
# Trial #26  | F1-score: 1.0000 | Inference Time: 58.127 ms
# Parameters: {'hidden_size': 183, 'num_layers': 4, 'lr': 5.163124910488014e-05, 'batch_size': 32}
# ------------------------------------------------------------
# Trial #47  | F1-score: 1.0000 | Inference Time: 57.880 ms
# Parameters: {'hidden_size': 116, 'num_layers': 1, 'lr': 0.0005430507564500919, 'batch_size': 128}
# ------------------------------------------------------------

# %% [markdown]
# In cybersecurity systems, achieving high classification accuracy is important, but inference speed is also critical.
#
# A highly accurate model may become impractical if:
#
# - Prediction latency is too high
# - Real-time detection is required
# - Computational resources are limited
#
# The Pareto Front analysis allows selecting architectures that satisfy operational constraints while maintaining strong detection performance.

# %%
plot_pareto_front(study)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plot_pareto_front(study)
#
# Cell In[20], line 2, in plot_pareto_front(study, save_path)
#       1 def plot_pareto_front(study, save_path="pareto_imbalance"):
# ----> 2     if save_path not in os.listdir("results/imbalance"):
#       3         os.makedirs(save_path, exist_ok=True)
#       4     pareto_trials = study.best_trials
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'results/imbalance'

# %%
def pareto_dataframe(study):

    rows = []

    for t in study.best_trials:

        rows.append({
            "Trial": t.number,
            "F1-score": round(t.values[0], 4),
            "Inference Time (ms)": round(t.values[1] * 1000, 3),
            "Hidden Size": t.params["hidden_size"],
            "Num Layers": t.params["num_layers"],
            "Learning Rate": t.params["lr"],
            "Batch Size": t.params["batch_size"]
        })

    df = pd.DataFrame(rows)

    return df

# %%
df_pareto = pareto_dataframe(study)

print(df_pareto)
# Out:
#    Trial  F1-score  Inference Time (ms)  Hidden Size  Num Layers  \
# 0      1    0.9999               48.241           45           5
# 1      3    1.0000               56.564          129           2
# 2     26    1.0000               58.127          183           4
# 3     47    1.0000               57.880          116           1
#
#    Learning Rate  Batch Size
# 0       0.000636         128
# 1       0.000685         128
# 2       0.000052          32
# 3       0.000543         128

# %%
df_pareto.to_csv("pareto_results.csv", index=False)

# %%
best_trial = df_pareto.iloc[1]

# %% [markdown]
# # **4.Train Best Model**

# %%
best_params = best_trial

final_model = build_model(
    hidden_size=int(best_params["Hidden Size"]),
    lr=float(best_params["Learning Rate"]),
    num_layers=int(best_params["Num Layers"])
)

history = final_model.fit(
    X_train,
    y_train,
    batch_size=int(best_params["Batch Size"]),
    epochs=20,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/20
# 48223/48223 [==============================] - 77s 2ms/step - loss: 9.0816e-04 - accuracy: 0.9998 - val_loss: 1.9210e-04 - val_accuracy: 1.0000
# Epoch 2/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 4.8320e-04 - accuracy: 1.0000 - val_loss: 3.1519e-04 - val_accuracy: 1.0000
# Epoch 3/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 4.1678e-04 - accuracy: 1.0000 - val_loss: 1.5698e-04 - val_accuracy: 1.0000
# Epoch 4/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 2.7828e-04 - accuracy: 1.0000 - val_loss: 4.3834e-04 - val_accuracy: 1.0000
# Epoch 5/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 2.6403e-04 - accuracy: 1.0000 - val_loss: 1.4040e-04 - val_accuracy: 1.0000
# Epoch 6/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 3.5758e-04 - accuracy: 1.0000 - val_loss: 3.9129e-04 - val_accuracy: 1.0000
# Epoch 7/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 2.2775e-04 - accuracy: 1.0000 - val_loss: 1.3596e-04 - val_accuracy: 1.0000
# Epoch 8/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 4.9501e-04 - accuracy: 1.0000 - val_loss: 1.4282e-04 - val_accuracy: 1.0000
# Epoch 9/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 1.7173e-04 - accuracy: 1.0000 - val_loss: 1.7229e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 2.8227e-04 - accuracy: 1.0000 - val_loss: 4.3717e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 2.4338e-04 - accuracy: 1.0000 - val_loss: 2.2558e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 1.4989e-04 - accuracy: 1.0000 - val_loss: 2.8367e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 48223/48223 [==============================] - 77s 2ms/step - loss: 5.8275e-04 - accuracy: 1.0000 - val_loss: 1.4376e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 48223/48223 [==============================] - 77s 2ms/step - loss: 2.3507e-04 - accuracy: 1.0000 - val_loss: 8.9328e-05 - val_accuracy: 1.0000
# Epoch 15/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 6.9897e-04 - accuracy: 1.0000 - val_loss: 1.8418e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 2.6948e-04 - accuracy: 1.0000 - val_loss: 3.3474e-04 - val_accuracy: 1.0000
# Epoch 17/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 2.4690e-04 - accuracy: 1.0000 - val_loss: 2.6547e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 48223/48223 [==============================] - 77s 2ms/step - loss: 1.8622e-04 - accuracy: 1.0000 - val_loss: 1.7906e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 48223/48223 [==============================] - 76s 2ms/step - loss: 2.4396e-04 - accuracy: 1.0000 - val_loss: 4.0579e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 48223/48223 [==============================] - 75s 2ms/step - loss: 2.5453e-04 - accuracy: 1.0000 - val_loss: 5.9743e-04 - val_accuracy: 1.0000

# %%
# Predictions
y_pred = final_model.predict(X_test, verbose=0)
y_pred = (y_pred > 0.5).astype(int).flatten()

# F1-score
test_f1 = f1_score(y_test, y_pred)



sample = X_test[:1]
times = []
final_model.predict(sample, verbose=0)

for _ in range(100):

    start = time.perf_counter()
    final_model.predict(sample, verbose=0)
    end = time.perf_counter()
    times.append(end - start)

# Average latency in milliseconds
avg_inference_time_ms = np.mean(times) * 1000

# Results
print(f"Test F1-score: {test_f1:.4f}")

print(
    f"Average Inference Time: "
    f"{avg_inference_time_ms:.4f} ms/sample"
)
# Out:
# Test F1-score: 1.0000
# Average Inference Time: 63.6665 ms/sample

# %% [markdown]
# ### **Metrics**

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("AUC:", tf.keras.metrics.AUC()(y_test, y_pred).numpy() )

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9999865207940082
# Precision: 0.999987532493439
# Recall: 0.999998961029246
# F1 Score: 0.9999932467286894
# AUC: 0.99693435
#
# Confusion Matrix:
# [[   3891      24]
#  [      2 1924980]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      3915
#            1       1.00      1.00      1.00   1924982
#
#     accuracy                           1.00   1928897
#    macro avg       1.00      1.00      1.00   1928897
# weighted avg       1.00      1.00      1.00   1928897

# %%
confusion_matrix_heatmap(y_test, y_pred, save_dir="results/imbalanced", model_name="Imbalanced Optuna MLP")
# Out:
# Confusion matrix saved to:
#  - results\plots\imbalanced_optuna_mlp_confusion_matrix.png
#  - results\plots\imbalanced_optuna_mlp_confusion_matrix.pdf

# %%
results = {

    "accuracy": float(
        accuracy_score(y_test, y_pred)
    ),

    "precision": float(
        precision_score(y_test, y_pred)
    ),

    "recall": float(
        recall_score(y_test, y_pred)
    ),

    "f1_score": float(
        f1_score(y_test, y_pred)
    ),

    "auc": float(
        tf.keras.metrics.AUC()(
            y_test,
            y_pred
        ).numpy()
    ),

    "inference_time_ms": avg_inference_time_ms,

    "confusion_matrix": confusion_matrix(
        y_test,
        y_pred
    ).tolist(),

    "classification_report": classification_report(
        y_test,
        y_pred,
        output_dict=True
    )
}

# %% [markdown]
# ### **Export results in json format**

# %%
os.makedirs("results", exist_ok=True)

# Export path
results_path = os.path.join(
    "results/imbalanced",
    "evaluation_results_imbalanced_optuna.json"
)

# Save results
with open(results_path, "w") as f:
    json.dump(
        results,
        f,
        indent=4
    )

print(f"Results exported to: {results_path}")
# Out:
# Results exported to: results/imbalanced\evaluation_results_imbalanced_optuna.json
